# %% [markdown]
# ### Parametrelerin Tahmin Edilmesi (Ağırlıkların Bulunması)
#
# Cost(b,w) = 1/2m * ∑((b + wx(i)) - y(i))^2
#
# > Ağırlıkları bulmak için yöntemler:
#
# 1. Analitik Çözüm: Normal Denklemler Yöntemi (En Küçük Kareler Yöntemi)
#
# <img src="data:image/png;base64,...">
#
# 2. Optimizasyon Çözümü: Gradient Descent
#
# <img src="https://tahaashtiani.com/assets/images/2020-01-01-Building-Gradient-Descent-for-Multivariate-Regression/img_6.png">
#
# Ağırlıkları güncelleyerek yeni ağırlıkları hesaplamak için kullanılan bir çözüm.
